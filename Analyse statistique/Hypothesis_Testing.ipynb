# %%
! pip install pymysql
# Out:
# ...
#   Obtaining dependency information for pymysql from https://files.pythonhosted.org/packages/0c/94/e4181a1f6286f545507528c78016e00065ea913276888db2262507693ce5/PyMySQL-1.1.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/45.0 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/45.0 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/45.0 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/45.0 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/45.0 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/45.0 kB ? eta -:--:--
#    --------------------------- ------------ 30.7/45.0 kB 50.4 kB/s eta 0:00:01
#    --------------------------- ------------ 30.7/45.0 kB 50.4 kB/s eta 0:00:01
#    ------------------------------------ --- 41.0/45.0 kB 56.2 kB/s eta 0:00:01
# ...

# %%
from sqlalchemy import create_engine

# %%
import pandas as pd
from scipy import stats

# %%
pd.set_option("display.max_columns", None)

# %%
# Connexion à une base MySQL
engine = create_engine("mysql+pymysql://root:password@localhost:3306/classicmodels")

# %% [markdown]
# # **Comparison of revenue's mean of offices in EMEA and those in NA**

# %%
# Faire des jointures entre les tables et les récuperer

df1 = pd.read_sql("Select o.* ," \
"e.*, c.*, p.* from offices o " \
"join employees e on e.officeCode = o.officeCode " \
"join customers c on c.salesRepEmployeeNumber = e.employeeNumber " \
"join payments p on p.customerNumber = c.customerNumber", con=engine)


df1
# Out:
#     officeCode           city            phone              addressLine1  \
# 0            4          Paris  +33 14 723 4404  43 Rue Jouffroy D'abbans
# 1            4          Paris  +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2            4          Paris  +33 14 723 4404  43 Rue Jouffroy D'abbans
# 3            1  San Francisco  +1 650 219 4782         100 Market Street
# 4            1  San Francisco  +1 650 219 4782         100 Market Street
# ..         ...            ...              ...                       ...
# 268          2         Boston  +1 215 837 0825          1550 Court Place
# 269          2         Boston  +1 215 837 0825          1550 Court Place
# 270          6         Sydney  +61 2 9264 2451     5-11 Wentworth Avenue
# 271          6         Sydney  +61 2 9264 2451     5-11 Wentworth Avenue
# 272          6         Sydney  +61 2 9264 2451     5-11 Wentworth Avenue
#
#     addressLine2 state    country postalCode territory  employeeNumber  \
# ...

# %%
df1.columns
# Out:
# Index(['officeCode', 'city', 'phone', 'addressLine1', 'addressLine2', 'state',
#        'country', 'postalCode', 'territory', 'employeeNumber', 'lastName',
#        'firstName', 'extension', 'email', 'officeCode', 'reportsTo',
#        'jobTitle', 'customerNumber', 'customerName', 'contactLastName',
#        'contactFirstName', 'phone', 'addressLine1', 'addressLine2', 'city',
#        'state', 'postalCode', 'country', 'salesRepEmployeeNumber',
#        'creditLimit', 'customerNumber', 'checkNumber', 'paymentDate',
#        'amount'],
#       dtype='object')

# %%
df1 = df1.loc[:, ~df1.columns.duplicated()]

# %%
df2 = df1[df1["territory"].isin(["EMEA", "NA"])]
df2
# Out:
#     officeCode           city             phone              addressLine1  \
# 0            4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 1            4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2            4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 3            1  San Francisco   +1 650 219 4782         100 Market Street
# 4            1  San Francisco   +1 650 219 4782         100 Market Street
# ..         ...            ...               ...                       ...
# 265          1  San Francisco   +1 650 219 4782         100 Market Street
# 266          7         London  +44 20 7877 2041       25 Old Broad Street
# 267          7         London  +44 20 7877 2041       25 Old Broad Street
# 268          2         Boston   +1 215 837 0825          1550 Court Place
# 269          2         Boston   +1 215 837 0825          1550 Court Place
#
#     addressLine2 state country postalCode territory  employeeNumber  \
# ...

# %%
df3 = df2[["officeCode", "city", "state", "country", "employeeNumber",	"territory", "employeeNumber", "lastName",	"firstName",	"email",	"reportsTo", 	"jobTitle",
           	"customerNumber",	"customerName", "checkNumber",	"paymentDate",	"amount"]]
df3
# Out:
#     officeCode           city state country  employeeNumber territory  \
# 0            4          Paris  None  France            1370      EMEA
# 1            4          Paris  None  France            1370      EMEA
# 2            4          Paris  None  France            1370      EMEA
# 3            1  San Francisco    CA     USA            1166        NA
# 4            1  San Francisco    CA     USA            1166        NA
# ..         ...            ...   ...     ...             ...       ...
# 265          1  San Francisco    CA     USA            1165        NA
# 266          7         London  None      UK            1501      EMEA
# 267          7         London  None      UK            1501      EMEA
# 268          2         Boston    MA     USA            1188        NA
# 269          2         Boston    MA     USA            1188        NA
#
#      employeeNumber   lastName firstName                           email  \
# ...

# %% [markdown]
# ## **Checking the normality of data**

# %%
grp_EMEA = df3.loc[df3["territory"] == "EMEA"]
grp_EMEA
# Out:
#     officeCode    city state country  employeeNumber territory  \
# 0            4   Paris  None  France            1370      EMEA
# 1            4   Paris  None  France            1370      EMEA
# 2            4   Paris  None  France            1370      EMEA
# 10           4   Paris  None  France            1370      EMEA
# 11           4   Paris  None  France            1370      EMEA
# ..         ...     ...   ...     ...             ...       ...
# 256          4   Paris  None  France            1401      EMEA
# 259          4   Paris  None  France            1702      EMEA
# 260          4   Paris  None  France            1702      EMEA
# 266          7  London  None      UK            1501      EMEA
# 267          7  London  None      UK            1501      EMEA
#
#      employeeNumber   lastName firstName                           email  \
# 0              1370  Hernandez    Gerard  ghernande@classicmodelcars.com
# ...

# %%
grp_NA = df3.loc[df3["territory"] == "NA"]
grp_NA
# Out:
#     officeCode           city state country  employeeNumber territory  \
# 3            1  San Francisco    CA     USA            1166        NA
# 4            1  San Francisco    CA     USA            1166        NA
# 5            1  San Francisco    CA     USA            1166        NA
# 17           1  San Francisco    CA     USA            1165        NA
# 18           1  San Francisco    CA     USA            1165        NA
# ..         ...            ...   ...     ...             ...       ...
# 263          3            NYC    NY     USA            1323        NA
# 264          1  San Francisco    CA     USA            1165        NA
# 265          1  San Francisco    CA     USA            1165        NA
# 268          2         Boston    MA     USA            1188        NA
# 269          2         Boston    MA     USA            1188        NA
#
#      employeeNumber  lastName firstName                           email  \
# ...

# %%
stats.shapiro(grp_EMEA["amount"])
# Out:
# ShapiroResult(statistic=0.9189806170921214, pvalue=9.843043348155202e-07)

# %% [markdown]
# Data are not normaly distributed, so let's apply non-parametric hypothesis testing

# %% [markdown]
# ## **Applying the right test**

# %%
stats.mannwhitneyu(grp_EMEA["amount"], grp_NA["amount"], alternative = "two-sided")
# Out:
# MannwhitneyuResult(statistic=6577.0, pvalue=0.7991841669957409)

# %% [markdown]
# pvalue is closed to 1. That means, the two groups have almost the same revenue's mean

# %% [markdown]
# # **Analyzing whether sales are significantly different accross product lines or not**

# %%
datf1 = pd.read_sql(
    """
    SELECT pdl.*, pd.*, od.*, o.*
    FROM productlines pdl
    JOIN products pd ON pdl.productLine = pd.productLine
    JOIN orderdetails od ON od.productCode = pd.productCode
    JOIN orders o ON o.orderNumber = od.orderNumber
    WHERE o.status = 'Shipped'
    """,
    con=engine
)

datf1
# Out:
#        productLine                                    textDescription  \
# 0     Vintage Cars  Our Vintage Car models realistically portray a...
# 1     Vintage Cars  Our Vintage Car models realistically portray a...
# 2     Vintage Cars  Our Vintage Car models realistically portray a...
# 3     Vintage Cars  Our Vintage Car models realistically portray a...
# 4     Vintage Cars  Our Vintage Car models realistically portray a...
# ...            ...                                                ...
# 2766  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 2767  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 2768  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 2769  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 2770  Classic Cars  Attention car enthusiasts: Make your wildest c...
#
#      htmlDescription image productCode                          productName  \
# ...

# %%
datf1 = datf1.loc[:, ~datf1.columns.duplicated()]
datf1
# Out:
#        productLine                                    textDescription  \
# 0     Vintage Cars  Our Vintage Car models realistically portray a...
# 1     Vintage Cars  Our Vintage Car models realistically portray a...
# 2     Vintage Cars  Our Vintage Car models realistically portray a...
# 3     Vintage Cars  Our Vintage Car models realistically portray a...
# 4     Vintage Cars  Our Vintage Car models realistically portray a...
# ...            ...                                                ...
# 2766  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 2767  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 2768  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 2769  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 2770  Classic Cars  Attention car enthusiasts: Make your wildest c...
#
#      htmlDescription image productCode                          productName  \
# ...

# %%
datf1.columns
# Out:
# Index(['productLine', 'textDescription', 'htmlDescription', 'image',
#        'productCode', 'productName', 'productScale', 'productVendor',
#        'productDescription', 'quantityInStock', 'buyPrice', 'MSRP',
#        'orderNumber', 'quantityOrdered', 'priceEach', 'orderLineNumber',
#        'orderDate', 'requiredDate', 'shippedDate', 'status', 'comments',
#        'customerNumber'],
#       dtype='object')

# %%
datf2 = datf1[['productLine',
       'productCode', 'productName', 'productScale', 'buyPrice', 'MSRP',
       'orderNumber', 'quantityOrdered', 'priceEach']]
datf2
# Out:
#        productLine productCode                          productName  \
# 0     Vintage Cars    S18_1749             1917 Grand Touring Sedan
# 1     Vintage Cars    S18_2248                   1911 Ford Town Car
# 2     Vintage Cars    S18_4409  1932 Alfa Romeo 8C2300 Spider Sport
# 3     Vintage Cars    S24_3969     1936 Mercedes Benz 500k Roadster
# 4     Vintage Cars    S18_2325            1932 Model A Ford J-Coupe
# ...            ...         ...                                  ...
# 2766  Classic Cars    S18_3232          1992 Ferrari 360 Spider red
# 2767  Classic Cars    S18_3685       1948 Porsche Type 356 Roadster
# 2768  Classic Cars    S24_2972              1982 Lamborghini Diablo
# 2769  Classic Cars    S24_3371            1971 Alpine Renault 1600s
# 2770  Classic Cars    S24_3856              1956 Porsche 356A Coupe
#
#      productScale  buyPrice    MSRP  orderNumber  quantityOrdered  priceEach
# ...

# %%
datf2["Amount"] = datf2["priceEach"]*datf2["quantityOrdered"]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_26300\2959870640.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datf2["Amount"] = datf2["priceEach"]*datf2["quantityOrdered"]

# %%
datf2["productLine"].unique()
# Out:
# array(['Vintage Cars', 'Classic Cars', 'Trucks and Buses', 'Trains',
#        'Ships', 'Planes', 'Motorcycles'], dtype=object)

# %%
grp_vint = datf2[datf2["productLine"] == 'Vintage Cars']
grp_clas = datf2[datf2["productLine"] == 'Classic Cars']
grp_truc = datf2[datf2["productLine"] == 'Trucks and Buses']
grp_tr = datf2[datf2["productLine"] == 'Trains']
grp_ships = datf2[datf2["productLine"] == 'Ships']
grp_planes = datf2[datf2["productLine"] == 'Planes']
grp_moto = datf2[datf2["productLine"] == 'Motorcycles']

# %% [markdown]
# ## **Checking the normality of data**

# %%
stats.shapiro(grp_vint["Amount"])
# Out:
# ShapiroResult(statistic=0.9383480947060481, pvalue=4.1288832393011e-15)

# %% [markdown]
# Data are not normaly distributed, so let's apply non-parametric hypothesis testing

# %% [markdown]
# ## **Applying the right test**

# %%
stats.kruskal(grp_vint["Amount"], grp_clas["Amount"], grp_truc["Amount"], 
              grp_tr["Amount"], grp_ships["Amount"], grp_planes["Amount"], grp_moto["Amount"])
# Out:
# KruskalResult(statistic=217.7472749669812, pvalue=3.144654948217092e-44)

# %% [markdown]
# pvalue is closed to 0. That means sales are significanty diffrenent accross productlines
